# %% [markdown]
# <a href="https://colab.research.google.com/github/TANKALANAGARAJU/fmml_assesments/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-27 04:28:37--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   213MB/s    in 0.3s
#
# 2023-05-27 04:28:40 (213 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 39369  1601.02644v2  3D gaze information is important for scene-cen...    cs
# 25311  1507.05717v1  Image-based sequence recognition has been a lo...    cs
# 36471   1401.6307v1  We show that the propositional model counting ...    cs
# 28839  1707.08722v1  In multiview geometry when correspondences amo...    cs
# 19807   1207.4119v1  The paper introduces mixed networks, a new fra...    cs
# ...             ...                                                ...   ...
# 5569    1303.0561v2  Decision tree learning is a popular approach f...  stat
# 7010   1709.01147v1  The PARAFAC tensor decomposition has enjoyed a...  stat
# 21376  1801.08287v2  This paper investigates estimating the varianc...    cs
# 2466   1612.00583v1  Autonomous systems can be used to search for s...  stat
# 13028  1502.04269v3  Scoring systems are linear classification mode...  stat
#
#                                                    title  year  \
# 39369  3D Gaze Estimation from 2D Pupil Positions on ...  2016
# 25311  An End-to-End Trainable Neural Network for Ima...  2015
# 36471  Hypergraph Acyclicity and Propositional Model ...  2014
# 28839  Algebraic Relations and Triangulation of Unlab...  2017
# 19807  Mixtures of Deterministic-Probabilistic Networ...  2012
# ...                                                  ...   ...
# 5569   Top-down particle filtering for Bayesian decis...  2013
# 7010   Balancing Interpretability and Predictive Accu...  2017
# 21376  Directly Estimating the Variance of the λ-Retu...  2018
# 2466   Active Search for Sparse Signals with Region S...  2016
# 13028  Supersparse Linear Integer Models for Optimize...  2015
#
#                                                 keywords
# 39369  [information, important, attention, estimation...
# 25311  [recognition, investigate, recognition, import...
# 36471  [propositional, hypergraphs, decomposition, po...
# 28839  [multiview, correspondences, understood, unlab...
# 19807  [introduces, framework, expressing, reasoning,...
# ...                                                  ...
# 5569   [classification, regression, statistics, formu...
# 7010   [decomposition, increasing, exploratory, scena...
# 21376  [investigates, estimating, difference, reinfor...
# 2466   [autonomous, intuitively, algorithms, efficien...
# 13028  [classification, prediction, widespread, commu...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 39369    [information, important, attention, estimation...
# 25311    [recognition, investigate, recognition, import...
# 36471    [propositional, hypergraphs, decomposition, po...
# 28839    [multiview, correspondences, understood, unlab...
# 19807    [introduces, framework, expressing, reasoning,...
#                                ...
# 14342    [component, statistical, representing, occurre...
# 23725    [recognition, identification, appropriate, ben...
# 21357       [associated, simulator, developing, algorithm]
# 14827    [dictionary, theoretic, dictionary, connected,...
# 5927     [increasing, specialized, important, algorithm...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8742 words.
# Out of those 4601 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="ea29f4ad-0b26-4de6-940e-098a57281346" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ea29f4ad-0b26-4de6-940e-098a57281346")) {                    Plotly.newPlot(                        "ea29f4ad-0b26-4de6-940e-098a57281346",                        [{"x":["important","challenging","coordinate","simulated","approaches","summarize","discussion","performance","estimation","directions","validation","different","demonstrate","procedures","environments","monocular","challenges","calibration","including","experimental","effectiveness","attention","information","positions","sequences","algorithms","effective","remarkable","performances","practical","scenarios","possesses","transcription","integrates","normalization","superiority","distinctive","arbitrary","components","trainable","generates","application","predefined","horizontal","framework","benchmarks","properties","segmentation","extraction","character","recognition","generality","involving","investigate","algorithm","experiments","naturally","architecture","separately","hypergraph","hypergraphs","extensions","decompositions","acyclicity","generalize","propositional","intractable","polynomial","furthermore","decomposition","incidence","otherwise","correspondences","multiview","unlabeled","regarding","configurations","algebraic","relations","situation","understood","triangulation","understanding","probabilistic","deterministic","resulting","introduces","introduce","representation","reasoning","conditional","tractable","processing","constraints","graphical","constraint","semantics","probability","solutions","expressing","exponentially","protection","difficult","explanations","identified","explainable","speculate","regulations","interfaces","statements","explanation","justified","classification","influence","regulation","evaluated","introduced","searching","modification","heuristically","developed","correctness","replicates","presented","theoretical","traditionally","complexity","comprehensive","montanari","literature","available","generating","considered","difficulty","automatically","addressing","automatic","contributing","structures","analytical","publications","contributions","categories","mechanism","knowledge","pragmatic","exploration","pharmaceutical","structure","determination","meaningful","conversations","scholarly","processes","inability","taxonomies","identifying","installed","calculate","prediction","embedding","labelling","applications","negatively","encapsulate","appropriate","isometric","linguistic","structured","downstream","hyperbolic","euclidean","significantly","similarity","representations","significant","dimensional","embeddings","completed","relevancy","inference","interface","analyzing","integrating","financial","malicious","detecting","preliminary","interactions","systematically","investigations","activations","corresponding","transformation","approximated","rectified","numerical","accurately","describes","stochastic"],"y":[382,265,30,54,433,22,29,884,184,38,50,758,577,44,85,19,112,18,262,401,201,161,700,24,99,587,278,28,53,137,99,11,9,25,30,29,14,85,108,22,42,241,11,9,537,79,209,216,139,66,383,15,57,156,796,537,56,238,30,3,3,33,12,2,52,29,14,62,165,73,5,28,15,5,48,45,25,15,83,31,25,5,184,132,36,155,81,319,375,131,98,30,295,142,51,94,109,175,134,12,26,6,118,18,51,4,2,1,17,15,16,10,502,55,6,129,119,28,35,4,184,13,1,151,160,14,216,62,1,106,297,97,137,54,186,24,198,10,130,25,7,47,67,116,357,7,52,3,350,12,57,18,2,83,5,4,74,2,16,226,109,8,433,3,2,85,2,69,94,10,4,35,277,165,243,267,185,73,4,1,195,42,60,32,15,6,76,37,81,24,7,30,140,62,13,6,86,80,76,125],"type":"bar"},{"x":["important","challenging","coordinate","simulated","approaches","summarize","discussion","performance" ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4601,), (4601, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8283333333333334

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Multi</span> <span style=''>source</span> <span style=''>feedback</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>appraisal</span> <span style=''>system</span> <span style=''>using</span> <span style=''>Fuzzy</span> <span style=''>logic</span> <span style=''>decision</span> <span style=''>support</span> <span style=''>system</span> <br/><br/><span style=''>In</span> <span style=''>Multi</span> <span style=''>Source</span> <span style=''>Feedback</span> <span style=''>or</span> <span style=''>360</span> <span style=''>Degree</span> <span style=''>Feedback</span> <span style=''>data</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>individual</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>collected</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>systematically</span> <span style=''>from</span> <span style=''>a</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.6);'>stakeholders</span> <span style=''>and</span> <span style=''>are</span> <span style=''>used</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.4050632911392405);'>improving</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>The</span> <span style=''>360</span> <span style=''>Degree</span> <span style=''>Feedback</span> <span style=''>approach</span> <span style=''>provides</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consistent</span> <span style='background-color:rgba(0, 255, 0, 0.4827586206896552);'>management</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>philosophy</span> <span style=''>meeting</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>criterion</span> <span style=''>outlined</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>previously</span> <span style=''>The</span> <span style=''>360</span> <span style=''>degree</span> <span style=''>feedback</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>appraisal</span> <span style=''>process</span> <span style='background-color:rgba(0, 255, 0, 0.46153846153846145);'>describes</span> <span style=''>a</span> <span style=''>human</span> <span style=''>resource</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>methodology</span> <span style=''>that</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>frequently</span> <span style=''>used</span> <span style=''>for</span> <span style=''>both</span> <span style=''>employee</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>appraisal</span> <span style=''>and</span> <span style=''>employee</span> <span style='background-color:rgba(0, 255, 0, 0.43455497382198954);'>development</span> <span style=''>Used</span> <span style=''>in</span> <span style=''>employee</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>appraisals</span> <span style=''>the</span> <span style=''>360</span> <span style=''>degree</span> <span style=''>feedback</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>methodology</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>differentiated</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>traditional</span> <span style=''>top</span> <span style=''>down</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>appraisal</span> <span style=''>methods</span> <span style=''>in</span> <span style=''>which</span> <span style=''>the</span>  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Data</span> <span style=''>driven</span> <span style=''>Optimal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Transport</span> <span style=''>Cost</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Selection</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Distributionally</span> <span style=''>Robust</span> <span style=''>Optimizatio</span> <br/><br/><span style=''>Recently</span> <span style=''>(Blanchet</span> <span style=''>Kang</span> <span style=''>and</span> <span style=''>Murhy</span> <span style=''>2016)</span> <span style=''>showed</span> <span style=''>that</span> <span style=''>several</span> <span style=''>machine</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>such</span> <span style=''>as</span> <span style=''>square</span> <span style=''>root</span> <span style=''>Lasso</span> <span style=''>Support</span> <span style=''>Vector</span> <span style=''>Machines</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularized</span> <span style=''>logistic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>among</span> <span style=''>many</span> <span style=''>others</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>represented</span> <span style=''>exactly</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributionally</span> <span style=''>robust</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>(DRO)</span> <span style=''>problems</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>uncertainty</span> <span style=''>is</span> <span style=''>defined</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>neighborhood</span> <span style=''>centered</span> <span style=''>at</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>empirical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>methodology</span> <span style=''>which</span> <span style=''>learns</span> <span style=''>such</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>neighborhood</span> <span style=''>in</span> <span style=''>a</span> <span style=''>natural</span> <span style=''>data</span> <span style=''>driven</span> <span style=''>way</span> <span style=''>We</span> <span style=''>show</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>rigorously</span> <span style=''>that</span> <span style=''>our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>encompasses</span> <span style=''>adaptive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularization</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style=''>case</span> <span style=''>Moreover</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>empirically</span> <span style=''>that</span> <span style=''>our</span> <span style=''>proposed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>methodology</span> <span style=''>is</span> <span style=''>able</span> <span style=''>to</span> <span style=''>improve</span> <span style=''>upon</span> <span style=''>a</span> <span style=''>wide</span> <span style=''>range</span> <span style=''>of</span> <span style=''>popular</span> <span style=''>m ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Block</span> <span style=''>diagonal</span> <span style=''>Hessian</span> <span style=''>free</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Optimization</span> <span style=''>for</span> <span style=''>Training</span> <span style=''>Neural</span> <span style=''>Networks</span> <br/><br/><span style=''>Second</span> <span style=''>order</span> <span style=''>methods</span> <span style=''>for</span> <span style=''>neural</span> <span style=''>network</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>have</span> <span style=''>several</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>advantages</span> <span style=''>over</span> <span style=''>methods</span> <span style=''>based</span> <span style=''>on</span> <span style=''>first</span> <span style=''>order</span> <span style=''>gradient</span> <span style=''>descent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>including</span> <span style=''>better</span> <span style=''>scaling</span> <span style=''>to</span> <span style=''>large</span> <span style=''>mini</span> <span style=''>batch</span> <span style=''>sizes</span> <span style=''>and</span> <span style=''>fewer</span> <span style=''>updates</span> <span style=''>needed</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.44072948328267475);'>convergence</span> <span style=''>But</span> <span style=''>they</span> <span style=''>are</span> <span style=''>rarely</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>deep</span> <span style=''>learning</span> <span style=''>in</span> <span style=''>practice</span> <span style=''>because</span> <span style=''>of</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computational</span> <span style=''>cost</span> <span style=''>and</span> <span style=''>the</span> <span style=''>need</span> <span style=''>for</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dependent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithmic</span> <span style='background-color:rgba(0, 255, 0, 0.4857142857142856);'>variations</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>variant</span> <span style=''>of</span> <span style=''>the</span> <span style=''>Hessian</span> <span style=''>free</span> <span style=''>method</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>leverages</span> <span style=''>a</span> <span style=''>block</span> <span style=''>diagonal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximation</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalized</span> <span style=''>Gauss</span> <span style=''>Newton</span> <span style=''>matrix</span> <span style=''>Our</span> <span style=''>method</span> <span style=''>computes</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.6250000000000001);'>curvature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximation</span> <span style=''>matrix</span> <span style=''>only</span> <span style=''>for</span> <span style=''>pairs</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <span style=''>from</span> <span style=''>the</span> <span style=''>same</span> <span style=''>layer</span> <span style=''>or</span> <span style=''>block</span> <span style=''>of</span> <span style=''>the</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>and</span> <span style=''>performs</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conjugate</span> <span style=''>gradient</span> <span style=''>updates</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>independently</span> <span style= ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Online</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Stochastic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Optimization</span> <span style=''>under</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Correlated</span> <span style=''>Bandit</span> <span style=''>Feedback</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>online</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>of</span> <span style=''>a</span> <span style=''>locally</span> <span style=''>smooth</span> <span style=''>function</span> <span style=''>under</span> <span style=''>bandit</span> <span style=''>feedback</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>the</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>confidence</span> <span style=''>tree</span> <span style=''>(HCT)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>any</span> <span style=''>time</span> <span style=''>mathcalX</span> <span style=''>armed</span> <span style=''>bandit</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>and</span> <span style=''>derive</span> <span style=''>regret</span> <span style=''>bounds</span> <span style=''>matching</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>existing</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dependency</span> <span style=''>on</span> <span style=''>number</span> <span style=''>of</span> <span style=''>steps</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>smoothness</span> <span style=''>factor</span> <span style=''>The</span> <span style=''>main</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>advantage</span> <span style=''>of</span> <span style=''>HCT</span> <span style=''>is</span> <span style=''>that</span> <span style=''>it</span> <span style=''>handles</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenging</span> <span style=''>case</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correlated</span> <span style=''>rewards</span> <span style=''>whereas</span> <span style=''>existing</span> <span style=''>methods</span> <span style=''>require</span> <span style=''>that</span> <span style=''>the</span> <span style=''>reward</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generating</span> <span style=''>process</span> <span style=''>of</span> <span style=''>each</span> <span style=''>arm</span> <span style=''>is</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>identically</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>independent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributed</span> <span style=''>(iid)</span> <span style=''>random</span> <span style=''>process</span> <span style=''>HCT</span> <span style=''>also</span> <span style=''>improves</span> <span style=''>on</span> <span style=''>the</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>its</span> <span style= ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.10634462869502523)
# 	knowledge (0.12869502523431867)
# 	segmentation (0.07786589762076424)
# 	experimental (0.14455659697188175)
# 	representation (0.13518385003604902)
# 	detection (0.1243691420331651)
# 	information (0.25234318673395817)
# 	different (0.2732516222062004)
# 	recognition (0.1380677721701514)
# 	convolutional (0.14347512617159336)
#
# Some Statistics words are:
# 	convergence (0.11697926949654491)
# 	theoretical (0.14264560710760119)
# 	stochastic (0.1362290227048371)
# 	variables (0.14313919052319843)
# 	estimation (0.17472852912142153)
# 	algorithm (0.3998025666337611)
# 	distribution (0.19151036525172754)
# 	dimensional (0.184106614017769)
# 	regression (0.17374136229022705)
# 	inference (0.19595261599210267)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="401604ec-8598-4be7-8a50-a4328d50f69f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("401604ec-8598-4be7-8a50-a4328d50f69f")) {                    Plotly.newPlot(                        "401604ec-8598-4be7-8a50-a4328d50f69f",                        [{"x":["important","challenging","coordinate","simulated","approaches","summarize","discussion","performance","estimation","directions","validation","different","demonstrate","procedures","environments","monocular","challenges","calibration","including","experimental","effectiveness","attention","information","positions","sequences","algorithms","effective","remarkable","performances","practical","scenarios","possesses","transcription","integrates","normalization","superiority","distinctive","arbitrary","components","trainable","generates","application","predefined","horizontal","framework","benchmarks","properties","segmentation","extraction","character","recognition","generality","involving","investigate","algorithm","experiments","naturally","architecture","separately","hypergraph","hypergraphs","extensions","decompositions","acyclicity","generalize","propositional","intractable","polynomial","furthermore","decomposition","incidence","otherwise","correspondences","multiview","unlabeled","regarding","configurations","algebraic","relations","situation","understood","triangulation","understanding","probabilistic","deterministic","resulting","introduces","introduce","representation","reasoning","conditional","tractable","processing","constraints","graphical","constraint","semantics","probability","solutions","expressing","exponentially","protection","difficult","explanations","identified","explainable","speculate","regulations","interfaces","statements","explanation","justified","classification","influence","regulation","evaluated","introduced","searching","modification","heuristically","developed","correctness","replicates","presented","theoretical","traditionally","complexity","comprehensive","montanari","literature","available","generating","considered","difficulty","automatically","addressing","automatic","contributing","structures","analytical","publications","contributions","categories","mechanism","knowledge","pragmatic","exploration","pharmaceutical","structure","determination","meaningful","conversations","scholarly","processes","inability","taxonomies","identifying","installed","calculate","prediction","embedding","labelling","applications","negatively","encapsulate","appropriate","isometric","linguistic","structured","downstream","hyperbolic","euclidean","significantly","similarity","representations","significant","dimensional","embeddings","completed","relevancy","inference","interface","analyzing","integrating","financial","malicious","detecting","preliminary","interactions","systematically","investigations","activations","corresponding","transformation","approximated","rectified","numerical","accurately","describes","stochastic","approximate","relatively","statistical","covariance","correspondence","distribution","approximation","factorial","simulations","theoretically","particular","questions","encountered","widespread","performed","detection","conventional","promising","autonomous","simultaneous","observations","conditions","trajectory","precision","estimating","navigation","inferring","convolutional","exploited","localization","techniques","environment","perception","understand","technologies","effectively","integrated","recognise","materials","discussing","temperature","accuracies","smartphone","ubiquitous","potentials","classifies","expectation","unsuitable","asymmetric","anomalies","functions","dedicated","likelihood","maximization","parameters","maximizing","heterogeneit ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	maximizer
# 	interpolate
# 	extrapolate
# 	indefinite
# 	stochasticity
# 	depression
# 	unequally
# 	integrable
# 	bernsteins
# 	semiparametric
# 	underpinning
# 	instabilities
# 	chebyshev
# 	parametrically
# 	resamples
# 	macroeconomic
# 	nonstationary
# 	topography
# 	confounding
# 	complemented
# Some words which never appear in Statistics papers:
# 	monocular
# 	acyclicity
# 	propositional
# 	correspondences
# 	speculate
# 	conversations
# 	scholarly
# 	taxonomies
# 	installed
# 	recognise
# 	generalisability
# 	contradicting
# 	accelerators
# 	withdrawn
# 	fabricated
# 	destructive
# 	accelerator
# 	kinectfusion
# 	researches
# 	prescription

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0920503385795126e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7925
